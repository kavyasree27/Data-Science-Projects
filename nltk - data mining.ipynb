# %%
import nltk

# %%
with open('brown_corpus_ca10.txt','r') as myfile:
    data = myfile.read().replace('\n','')

# %%
data
# Out:
# "\tVincent/np G./np Ierulli/np has/hvz been/ben appointed/vbn temporary/jj assistant/nn district/nn attorney/nn ,/, it/pps was/bedz announced/vbn Monday/nr by/in Charles/np E./np Raymond/np ,/, District/nn-tl Attorney/nn-tl ./.\tIerulli/np will/md replace/vb Desmond/np D./np Connall/np who/wps has/hvz been/ben called/vbn to/in active/jj military/jj service/nn but/cc is/bez expected/vbn back/rb on/in the/at job/nn by/in March/np 31/cd ./.\tIerulli/np ,/, 29/cd ,/, has/hvz been/ben practicing/vbg in/in Portland/np since/in November/np ,/, 1959/cd ./.He/pps is/bez a/at graduate/nn of/in Portland/np-tl University/nn-tl and/cc the/at Northwestern/jj-tl College/nn-tl of/in-tl Law/nn-tl ./.He/pps is/bez married/vbn and/cc the/at father/nn of/in three/cd children/nns ./.\tHelping/vbg foreign/jj countries/nns to/to build/vb a/at sound/jj political/jj structure/nn is/bez more/ql important/jj than/cs aiding/vbg them/ppo economically/rb ,/, E./np M./np Martin/np ,/, assistant/nn secretary/nn of/
# ...

# %%
data2 = data.replace("/","")

# %%
data2
# Out:
# "\tVincentnp G.np Ierullinp hashvz beenben appointedvbn temporaryjj assistantnn districtnn attorneynn ,, itpps wasbedz announcedvbn Mondaynr byin Charlesnp E.np Raymondnp ,, Districtnn-tl Attorneynn-tl ..\tIerullinp willmd replacevb Desmondnp D.np Connallnp whowps hashvz beenben calledvbn toin activejj militaryjj servicenn butcc isbez expectedvbn backrb onin theat jobnn byin Marchnp 31cd ..\tIerullinp ,, 29cd ,, hashvz beenben practicingvbg inin Portlandnp sincein Novembernp ,, 1959cd ..Hepps isbez aat graduatenn ofin Portlandnp-tl Universitynn-tl andcc theat Northwesternjj-tl Collegenn-tl ofin-tl Lawnn-tl ..Hepps isbez marriedvbn andcc theat fathernn ofin threecd childrennns ..\tHelpingvbg foreignjj countriesnns toto buildvb aat soundjj politicaljj structurenn isbez moreql importantjj thancs aidingvbg themppo economicallyrb ,, E.np M.np Martinnp ,, assistantnn secretarynn ofin statenn forin economicjj affairsnns toldvbd membersnns ofin theat Worldnn-tl Affairsnns-tl Councilnn-tl Mon
# ...

# %%
for i, line in enumerate(data2.split('/n')):
    if i>10:
        break
    print(str(i) + ':\t'+ line)
# Out:
# 0:		Vincentnp G.np Ierullinp hashvz beenben appointedvbn temporaryjj assistantnn districtnn attorneynn ,, itpps wasbedz announcedvbn Mondaynr byin Charlesnp E.np Raymondnp ,, Districtnn-tl Attorneynn-tl ..	Ierullinp willmd replacevb Desmondnp D.np Connallnp whowps hashvz beenben calledvbn toin activejj militaryjj servicenn butcc isbez expectedvbn backrb onin theat jobnn byin Marchnp 31cd ..	Ierullinp ,, 29cd ,, hashvz beenben practicingvbg inin Portlandnp sincein Novembernp ,, 1959cd ..Hepps isbez aat graduatenn ofin Portlandnp-tl Universitynn-tl andcc theat Northwesternjj-tl Collegenn-tl ofin-tl Lawnn-tl ..Hepps isbez marriedvbn andcc theat fathernn ofin threecd childrennns ..	Helpingvbg foreignjj countriesnns toto buildvb aat soundjj politicaljj structurenn isbez moreql importantjj thancs aidingvbg themppo economicallyrb ,, E.np M.np Martinnp ,, assistantnn secretarynn ofin statenn forin economicjj affairsnns toldvbd membersnns ofin theat Worldnn-tl Affairsnns-tl Councilnn-tl Monda
# ...

# %%
from nltk import sent_tokenize,word_tokenize

# %%
sent_tokenize(data2)
# Out:
# ["\tVincentnp G.np Ierullinp hashvz beenben appointedvbn temporaryjj assistantnn districtnn attorneynn ,, itpps wasbedz announcedvbn Mondaynr byin Charlesnp E.np Raymondnp ,, Districtnn-tl Attorneynn-tl ..\tIerullinp willmd replacevb Desmondnp D.np Connallnp whowps hashvz beenben calledvbn toin activejj militaryjj servicenn butcc isbez expectedvbn backrb onin theat jobnn byin Marchnp 31cd ..\tIerullinp ,, 29cd ,, hashvz beenben practicingvbg inin Portlandnp sincein Novembernp ,, 1959cd ..Hepps isbez aat graduatenn ofin Portlandnp-tl Universitynn-tl andcc theat Northwesternjj-tl Collegenn-tl ofin-tl Lawnn-tl ..Hepps isbez marriedvbn andcc theat fathernn ofin threecd childrennns ..\tHelpingvbg foreignjj countriesnns toto buildvb aat soundjj politicaljj structurenn isbez moreql importantjj thancs aidingvbg themppo economicallyrb ,, E.np M.np Martinnp ,, assistantnn secretarynn ofin statenn forin economicjj affairsnns toldvbd membersnns ofin theat Worldnn-tl Affairsnns-tl Councilnn-tl Mo
# ...

# %%
for sent in sent_tokenize(data2):
    print(word_tokenize(sent))
# Out:
# ['Vincentnp', 'G.np', 'Ierullinp', 'hashvz', 'beenben', 'appointedvbn', 'temporaryjj', 'assistantnn', 'districtnn', 'attorneynn', ',', ',', 'itpps', 'wasbedz', 'announcedvbn', 'Mondaynr', 'byin', 'Charlesnp', 'E.np', 'Raymondnp', ',', ',', 'Districtnn-tl', 'Attorneynn-tl', '..', 'Ierullinp', 'willmd', 'replacevb', 'Desmondnp', 'D.np', 'Connallnp', 'whowps', 'hashvz', 'beenben', 'calledvbn', 'toin', 'activejj', 'militaryjj', 'servicenn', 'butcc', 'isbez', 'expectedvbn', 'backrb', 'onin', 'theat', 'jobnn', 'byin', 'Marchnp', '31cd', '..', 'Ierullinp', ',', ',', '29cd', ',', ',', 'hashvz', 'beenben', 'practicingvbg', 'inin', 'Portlandnp', 'sincein', 'Novembernp', ',', ',', '1959cd', '..', 'Hepps', 'isbez', 'aat', 'graduatenn', 'ofin', 'Portlandnp-tl', 'Universitynn-tl', 'andcc', 'theat', 'Northwesternjj-tl', 'Collegenn-tl', 'ofin-tl', 'Lawnn-tl', '..', 'Hepps', 'isbez', 'marriedvbn', 'andcc', 'theat', 'fathernn', 'ofin', 'threecd', 'childrennns', '..', 'Helpingvbg', 'foreignjj', 'countr
# ...

# %%
from nltk.corpus import stopwords

# %%
stopwords_en = stopwords.words('english')

# %%
single_tokenize_lower = list(map(str.lower,word_tokenize(data2)))
print(single_tokenize_lower)
# Out:
# ['vincentnp', 'g.np', 'ierullinp', 'hashvz', 'beenben', 'appointedvbn', 'temporaryjj', 'assistantnn', 'districtnn', 'attorneynn', ',', ',', 'itpps', 'wasbedz', 'announcedvbn', 'mondaynr', 'byin', 'charlesnp', 'e.np', 'raymondnp', ',', ',', 'districtnn-tl', 'attorneynn-tl', '..', 'ierullinp', 'willmd', 'replacevb', 'desmondnp', 'd.np', 'connallnp', 'whowps', 'hashvz', 'beenben', 'calledvbn', 'toin', 'activejj', 'militaryjj', 'servicenn', 'butcc', 'isbez', 'expectedvbn', 'backrb', 'onin', 'theat', 'jobnn', 'byin', 'marchnp', '31cd', '..', 'ierullinp', ',', ',', '29cd', ',', ',', 'hashvz', 'beenben', 'practicingvbg', 'inin', 'portlandnp', 'sincein', 'novembernp', ',', ',', '1959cd', '..', 'hepps', 'isbez', 'aat', 'graduatenn', 'ofin', 'portlandnp-tl', 'universitynn-tl', 'andcc', 'theat', 'northwesternjj-tl', 'collegenn-tl', 'ofin-tl', 'lawnn-tl', '..', 'hepps', 'isbez', 'marriedvbn', 'andcc', 'theat', 'fathernn', 'ofin', 'threecd', 'childrennns', '..', 'helpingvbg', 'foreignjj', 'countr
# ...

# %%
stopwords_en = set(stopwords.words('english'))

# %%
print([word for word in single_tokenize_lower if word not in stopwords_en])
# Out:
# ['vincentnp', 'g.np', 'ierullinp', 'hashvz', 'beenben', 'appointedvbn', 'temporaryjj', 'assistantnn', 'districtnn', 'attorneynn', ',', ',', 'itpps', 'wasbedz', 'announcedvbn', 'mondaynr', 'byin', 'charlesnp', 'e.np', 'raymondnp', ',', ',', 'districtnn-tl', 'attorneynn-tl', '..', 'ierullinp', 'willmd', 'replacevb', 'desmondnp', 'd.np', 'connallnp', 'whowps', 'hashvz', 'beenben', 'calledvbn', 'toin', 'activejj', 'militaryjj', 'servicenn', 'butcc', 'isbez', 'expectedvbn', 'backrb', 'onin', 'theat', 'jobnn', 'byin', 'marchnp', '31cd', '..', 'ierullinp', ',', ',', '29cd', ',', ',', 'hashvz', 'beenben', 'practicingvbg', 'inin', 'portlandnp', 'sincein', 'novembernp', ',', ',', '1959cd', '..', 'hepps', 'isbez', 'aat', 'graduatenn', 'ofin', 'portlandnp-tl', 'universitynn-tl', 'andcc', 'theat', 'northwesternjj-tl', 'collegenn-tl', 'ofin-tl', 'lawnn-tl', '..', 'hepps', 'isbez', 'marriedvbn', 'andcc', 'theat', 'fathernn', 'ofin', 'threecd', 'childrennns', '..', 'helpingvbg', 'foreignjj', 'countr
# ...

# %%
from string import punctuation

# %%
print('From string.punctuation:', type(punctuation),punctuation)
# Out:
# From string.punctuation: <class 'str'> !"#$%&'()*+,-./:;<=>?@[\]^_`{|}~

# %%
stopwords_en_withpunct = stopwords_en.union(set(punctuation))

# %%
print(stopwords_en_withpunct)
# Out:
# {'couldn', '`', 'am', 'where', 'same', 'was', ')', 'itself', '+', 've', 'do', 'but', 'no', "mightn't", 'd', 'needn', 'ours', "hadn't", '(', 'them', 'after', 'wasn', 'being', 'under', 'other', '#', ',', 'o', 'these', '*', 'yours', 'll', 'than', 're', 'aren', 'are', 'doing', 'over', "couldn't", 'if', 'some', 'been', 'my', 'from', 'up', 'about', 'doesn', 'between', 'mightn', 'theirs', 'on', 'again', 'had', 'does', '/', 'why', '~', '=', 'can', '[', 'those', "it's", 'we', '@', '}', '>', 'they', 'this', "won't", 'yourself', 'against', 'both', 'our', 'own', "isn't", "'", 'when', 'won', '&', 'as', 'a', 't', 'before', "shouldn't", '.', 'just', 'myself', 'ma', 'didn', 'be', 'wouldn', '_', "shan't", '{', 'by', 'have', 'himself', 'hasn', "haven't", '<', '$', "mustn't", 'i', 'did', "you'd", 'in', 'then', 'what', 'nor', '!', 'of', 'very', "you've", 'herself', 'his', 'their', 'during', 'there', 'above', "don't", 'not', ';', 'until', 'should', '?', 'having', 'will', 'don', ']', 'below', 'shan', 'any
# ...

# %%
print([word for word in single_tokenize_lower if word not in stopwords_en_withpunct])
# Out:
# ['vincentnp', 'g.np', 'ierullinp', 'hashvz', 'beenben', 'appointedvbn', 'temporaryjj', 'assistantnn', 'districtnn', 'attorneynn', 'itpps', 'wasbedz', 'announcedvbn', 'mondaynr', 'byin', 'charlesnp', 'e.np', 'raymondnp', 'districtnn-tl', 'attorneynn-tl', '..', 'ierullinp', 'willmd', 'replacevb', 'desmondnp', 'd.np', 'connallnp', 'whowps', 'hashvz', 'beenben', 'calledvbn', 'toin', 'activejj', 'militaryjj', 'servicenn', 'butcc', 'isbez', 'expectedvbn', 'backrb', 'onin', 'theat', 'jobnn', 'byin', 'marchnp', '31cd', '..', 'ierullinp', '29cd', 'hashvz', 'beenben', 'practicingvbg', 'inin', 'portlandnp', 'sincein', 'novembernp', '1959cd', '..', 'hepps', 'isbez', 'aat', 'graduatenn', 'ofin', 'portlandnp-tl', 'universitynn-tl', 'andcc', 'theat', 'northwesternjj-tl', 'collegenn-tl', 'ofin-tl', 'lawnn-tl', '..', 'hepps', 'isbez', 'marriedvbn', 'andcc', 'theat', 'fathernn', 'ofin', 'threecd', 'childrennns', '..', 'helpingvbg', 'foreignjj', 'countriesnns', 'toto', 'buildvb', 'aat', 'soundjj', 'pol
# ...

# %%
from nltk.stem import PorterStemmer
porter = PorterStemmer()

for word in single_tokenize_lower:
    print(porter.stem(word))
# Out:
# vincentnp
# g.np
# ierullinp
# hashvz
# beenben
# appointedvbn
# temporaryjj
# assistantnn
# districtnn
# attorneynn
# ,
# ,
# itpp
# wasbedz
# announcedvbn
# mondaynr
# byin
# charlesnp
# e.np
# raymondnp
# ,
# ,
# districtnn-tl
# attorneynn-tl
# ..
# ierullinp
# willmd
# replacevb
# desmondnp
# d.np
# connallnp
# whowp
# hashvz
# beenben
# calledvbn
# toin
# activejj
# militaryjj
# servicenn
# butcc
# isbez
# expectedvbn
# backrb
# onin
# theat
# jobnn
# byin
# marchnp
# 31cd
# ..
# ierullinp
# ,
# ,
# 29cd
# ,
# ,
# hashvz
# beenben
# practicingvbg
# inin
# portlandnp
# sincein
# novembernp
# ,
# ,
# 1959cd
# ..
# hepp
# isbez
# aat
# graduatenn
# ofin
# portlandnp-tl
# universitynn-tl
# andcc
# theat
# northwesternjj-tl
# collegenn-tl
# ofin-tl
# lawnn-tl
# ..
# hepp
# isbez
# marriedvbn
# andcc
# theat
# fathernn
# ofin
# threecd
# childrennn
# ..
# helpingvbg
# foreignjj
# countriesnn
# toto
# buildvb
# aat
# soundjj
# politicaljj
# structurenn
# isbez
# moreql
# importantjj
# ...

# %%
from nltk.stem import WordNetLemmatizer
wnl = WordNetLemmatizer()

# %%
for word in single_tokenize_lower:
    print(wnl.lemmatize(word))
# Out:
# vincentnp
# g.np
# ierullinp
# hashvz
# beenben
# appointedvbn
# temporaryjj
# assistantnn
# districtnn
# attorneynn
# ,
# ,
# itpps
# wasbedz
# announcedvbn
# mondaynr
# byin
# charlesnp
# e.np
# raymondnp
# ,
# ,
# districtnn-tl
# attorneynn-tl
# ..
# ierullinp
# willmd
# replacevb
# desmondnp
# d.np
# connallnp
# whowps
# hashvz
# beenben
# calledvbn
# toin
# activejj
# militaryjj
# servicenn
# butcc
# isbez
# expectedvbn
# backrb
# onin
# theat
# jobnn
# byin
# marchnp
# 31cd
# ..
# ierullinp
# ,
# ,
# 29cd
# ,
# ,
# hashvz
# beenben
# practicingvbg
# inin
# portlandnp
# sincein
# novembernp
# ,
# ,
# 1959cd
# ..
# hepps
# isbez
# aat
# graduatenn
# ofin
# portlandnp-tl
# universitynn-tl
# andcc
# theat
# northwesternjj-tl
# collegenn-tl
# ofin-tl
# lawnn-tl
# ..
# hepps
# isbez
# marriedvbn
# andcc
# theat
# fathernn
# ofin
# threecd
# childrennns
# ..
# helpingvbg
# foreignjj
# countriesnns
# toto
# buildvb
# aat
# soundjj
# politicaljj
# structurenn
# isbez
# moreql
# ...

# %%
stop_words = set(stopwords.words('english'))
tokenized = sent_tokenize(data2)
for i in tokenized:
    wordlist = nltk.word_tokenize(i)
    wordlist = [w for w in wordlist if not w in stop_words]
    tagged = nltk.pos_tag(wordlist)
    
    print(tagged)
# Out:
# [('Vincentnp', 'NNP'), ('G.np', 'NNP'), ('Ierullinp', 'NNP'), ('hashvz', 'NN'), ('beenben', 'NN'), ('appointedvbn', 'NN'), ('temporaryjj', 'NN'), ('assistantnn', 'NN'), ('districtnn', 'NN'), ('attorneynn', 'NN'), (',', ','), (',', ','), ('itpps', 'JJ'), ('wasbedz', 'NN'), ('announcedvbn', 'NN'), ('Mondaynr', 'NNP'), ('byin', 'NN'), ('Charlesnp', 'NNP'), ('E.np', 'NNP'), ('Raymondnp', 'NNP'), (',', ','), (',', ','), ('Districtnn-tl', 'NNP'), ('Attorneynn-tl', 'NNP'), ('..', 'NNP'), ('Ierullinp', 'NNP'), ('willmd', 'VBD'), ('replacevb', 'JJ'), ('Desmondnp', 'NNP'), ('D.np', 'NNP'), ('Connallnp', 'NNP'), ('whowps', 'VBD'), ('hashvz', 'JJ'), ('beenben', 'NN'), ('calledvbn', 'NN'), ('toin', 'NN'), ('activejj', 'NN'), ('militaryjj', 'NN'), ('servicenn', 'NN'), ('butcc', 'NN'), ('isbez', 'NN'), ('expectedvbn', 'NN'), ('backrb', 'NN'), ('onin', 'NN'), ('theat', 'NN'), ('jobnn', 'NN'), ('byin', 'NN'), ('Marchnp', 'NNP'), ('31cd', 'CD'), ('..', 'NNP'), ('Ierullinp', 'NNP'), (',', ','), (',', '
# ...

# %%
sentences = nltk.sent_tokenize(data2)
tokenized_sentences = [nltk.word_tokenize(sentence) for sentence in sentences]

# %%
tokenized_sentences
# Out:
# [['Vincentnp',
#   'G.np',
#   'Ierullinp',
#   'hashvz',
#   'beenben',
#   'appointedvbn',
#   'temporaryjj',
#   'assistantnn',
#   'districtnn',
#   'attorneynn',
#   ',',
#   ',',
#   'itpps',
#   'wasbedz',
#   'announcedvbn',
#   'Mondaynr',
#   'byin',
#   'Charlesnp',
#   'E.np',
#   'Raymondnp',
#   ',',
#   ',',
#   'Districtnn-tl',
#   'Attorneynn-tl',
#   '..',
#   'Ierullinp',
#   'willmd',
#   'replacevb',
#   'Desmondnp',
#   'D.np',
#   'Connallnp',
#   'whowps',
#   'hashvz',
#   'beenben',
#   'calledvbn',
#   'toin',
#   'activejj',
#   'militaryjj',
#   'servicenn',
#   'butcc',
#   'isbez',
#   'expectedvbn',
#   'backrb',
#   'onin',
#   'theat',
#   'jobnn',
#   'byin',
#   'Marchnp',
#   '31cd',
#   '..',
#   'Ierullinp',
#   ',',
#   ',',
#   '29cd',
#   ',',
#   ',',
#   'hashvz',
#   'beenben',
#   'practicingvbg',
#   'inin',
#   'Portlandnp',
#   'sincein',
#   'Novembernp',
#   ',',
#   ',',
#   '1959cd',
#   '..',
#   'Hepps',
#   'isbez',
#   'aat',
# ...

# %%
tagged_sentences = [nltk.pos_tag(sentence) for sentence in tokenized_sentences]
chunked_sentences =nltk.ne_chunk_sents(tagged_sentences,binary=True)

# %%
tagged_sentences
# Out:
# [[('Vincentnp', 'NNP'),
#   ('G.np', 'NNP'),
#   ('Ierullinp', 'NNP'),
#   ('hashvz', 'NN'),
#   ('beenben', 'NN'),
#   ('appointedvbn', 'NN'),
#   ('temporaryjj', 'NN'),
#   ('assistantnn', 'NN'),
#   ('districtnn', 'NN'),
#   ('attorneynn', 'NN'),
#   (',', ','),
#   (',', ','),
#   ('itpps', 'JJ'),
#   ('wasbedz', 'NN'),
#   ('announcedvbn', 'NN'),
#   ('Mondaynr', 'NNP'),
#   ('byin', 'NN'),
#   ('Charlesnp', 'NNP'),
#   ('E.np', 'NNP'),
#   ('Raymondnp', 'NNP'),
#   (',', ','),
#   (',', ','),
#   ('Districtnn-tl', 'NNP'),
#   ('Attorneynn-tl', 'NNP'),
#   ('..', 'NNP'),
#   ('Ierullinp', 'NNP'),
#   ('willmd', 'VBD'),
#   ('replacevb', 'JJ'),
#   ('Desmondnp', 'NNP'),
#   ('D.np', 'NNP'),
#   ('Connallnp', 'NNP'),
#   ('whowps', 'VBD'),
#   ('hashvz', 'JJ'),
#   ('beenben', 'NN'),
#   ('calledvbn', 'NN'),
#   ('toin', 'NN'),
#   ('activejj', 'NN'),
#   ('militaryjj', 'NN'),
#   ('servicenn', 'NN'),
#   ('butcc', 'NN'),
#   ('isbez', 'NN'),
#   ('expectedvbn', 'NN'),
# ...

# %%
chunked_sentences
# Out:
# <generator object ParserI.parse_sents.<locals>.<genexpr> at 0x121a59c78>

# %%
def extract_entity_name(t):
    entity_names =[]
    
    if hasattr(t,'label') and t.label:
        if t.label == 'NE':
            entity_names.append(' '.join([child[0] for child in t]))
        else:
            for child in t:
                entity_names.extend(exact_entity_name(child))
                
    return entity_names

# %%
entity_names
# Out:
# []

# %%
entity_names = []
for tree in chunked_sentences:
    entity_names.extend(extract_entity_name(tree))
    
    
print(set(entity_names))
# Out:
# set()
